# %% [markdown]
# # Backtest Example
#
# In this notebook I will demonstrate a dynamic scan over several data feeds.
# To simulate a scan I attached each stock with months in which it is allowed to be bought, as if it was shown in the scans in those months.
# NVDA (1,7)
# AAPL (2,8)
# MSFT (3,9)
# GOOG (4,10)
# TSLA (5,11)
# AMZN (6,12)
#
# Buying criteria:
# - Current month is an allowed month
# - 10 ema and 21 ema sloping upward
# - 10 ema above 21 ema
#
# Selling criteria:
# - 10 ema and 21 ema sloping down
# - 10 ema below 21 ema

# %%
from datetime import datetime
import backtrader as bt
from backtrader.analyzers import AnnualReturn, TradeAnalyzer
import yfinance as yf
from stats.tradeLog import TradeLog
from stats.strategySummery import build_summary_report
from stats.exporter import export_csv


class SmaCross(bt.Strategy):
    params = dict(
        period_fast=10,
        period_slow=21
    )

    def __init__(self):
        self.sma_pairs = []

        i = 1
        for data in self.datas:
            sma10 = bt.ind.SMA(data, period=self.p.period_fast)
            sma21 = bt.ind.SMA(data, period=self.p.period_slow)
            months_to_trade = [i, i+6]
            self.sma_pairs.append((data, sma10, sma21, months_to_trade))
            i = i + 1

    def next(self):
        for data, sma10, sma21, months_to_trade in self.sma_pairs:
            if not len(data) > self.p.period_slow:
                continue

            current_date = self.data.datetime.date(0)
            is_positioned = self.getposition(data)

            sma10_above_sma21 = sma10[0] > sma21[0]
            sma10_sloping_up = sma10[0] > sma10[-1]
            sma21_sloping_up = sma21[0] > sma21[-1]

            if not is_positioned and current_date.month in months_to_trade:
                if sma10_above_sma21 and sma10_sloping_up and sma21_sloping_up:
                    self.buy(data=data, size=10)

            elif is_positioned:
                if not sma10_above_sma21 and not sma10_sloping_up and not sma21_sloping_up:
                    self.close(data=data)


stocks_pool = ["NVDA", "AAPL", "MSFT", "GOOG", "TSLA", "AMZN"]

cerebro = bt.Cerebro()
cerebro.addsizer(bt.sizers.PercentSizer)
cerebro.broker.setcash(100000)

for stock in stocks_pool:
    stocks_data = yf.download(stock, start=datetime(2017, 1, 1), end=datetime(2024, 12, 31))
    stocks_data.columns = ["Open", "High", "Low", "Close", "Volume"] # Compatability with backtrader pandasData format
    stock_datafeed = bt.feeds.PandasData(dataname=stocks_data, name=stock)
    cerebro.adddata(stock_datafeed)

cerebro.addstrategy(SmaCross)
cerebro.addanalyzer(TradeLog, _name='trade_log')
sma_cross_strategy = cerebro.run()[0]

trade_table = sma_cross_strategy.analyzers.trade_log.get_analysis()
strategy_name = sma_cross_strategy.__class__.__name__
report = build_summary_report(sma_cross_strategy)
log_path = export_csv(trade_table, strategy_name)
summary_csv_path = export_csv(report, strategy_name)



cerebro.plot()
sma_cross_strategy.analyzers[0].get_analysis()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# <div id='830377cc-eaa2-4878-8864-f6e0de913b84'></div>
# [{'trade_id': 5,
#   'data_name': 'AMZN',
#   'side': 'long',
#   'entry_time': '2017-06-02T00:00:00',
#   'exit_time': '2017-06-13T00:00:00',
#   'entry_price': 50.33649826049805,
#   'exit_price': 34.20589116968116,
#   'size': 10.0,
#   'position_value_at_entry': 503.36498260498047,
#   'position_fraction_of_equity': 0.005024495796943983,
#   'pnl_abs': 43.22338104248047,
#   'pnl_pct': 0.08586886759343836,
#   'holding_period_days': 11.0},
#  {'trade_id': 6,
#   'data_name': 'GOOG',
#   'side': 'short',
#   'entry_time': '2017-06-28T00:00:00',
#   'exit_time': '2017-06-28T00:00:00',
#   'entry_price': 42.84479904174805,
#   'exit_price': 46.134291100136075,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 38.60088348388672,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 7,
#   'data_name': 'MSFT',
#   'side': 'short',
#   'entry_time': '2017-06-29T00:00:00',
#   'exit_time': '2017-06-29T00:00:00',
#   'entry_price': 58.152130126953125,
#   'exit_price': 63.15518754573831,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 41.92909240722656,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 8,
#   'data_name': 'AMZN',
#   'side': 'short',
#   'entry_time': '2017-06-29T00:00:00',
#   'exit_time': '2017-06-29T00:00:00',
#   'entry_price': 50.33649826049805,
#   'exit_price': 48.95000076293945,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -15.399971008300781,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 9,
#   'data_name': 'TSLA',
#   'side': 'short',
#   'entry_time': '2017-07-07T00:00:00',
#   'exit_time': '2017-07-07T00:00:00',
#   'entry_price': 21.25933265686035,
#   'exit_price': 20.899999618530273,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -3.7800025939941406,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 12,
#   'data_name': 'NVDA',
#   'side': 'short',
#   'entry_time': '2017-08-23T00:00:00',
#   'exit_time': '2017-08-23T00:00:00',
#   'entry_price': 4.075348377227783,
#   'exit_price': 3.9825842701649643,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 0.20882606506347656,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 14,
#   'data_name': 'AAPL',
#   'side': 'short',
#   'entry_time': '2017-09-22T00:00:00',
#   'exit_time': '2017-09-22T00:00:00',
#   'entry_price': 36.16071319580078,
#   'exit_price': 35.36230620987694,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -7.167320251464844,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 16,
#   'data_name': 'MSFT',
#   'side': 'short',
#   'entry_time': '2017-10-04T00:00:00',
#   'exit_time': '2017-10-04T00:00:00',
#   'entry_price': 67.36267852783203,
#   'exit_price': 67.80192242160562,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 9.883270263671875,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 18,
#   'data_name': 'GOOG',
#   'side': 'short',
#   'entry_time': '2017-12-07T00:00:00',
#   'exit_time': '2017-12-07T00:00:00',
#   'entry_price': 47.56401062011719,
#   'exit_price': 50.67471474337887,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 36.321372985839844,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 22,
#   'data_name': 'MSFT',
#   'side': 'short',
#   'entry_time': '2018-03-26T00:00:00',
#   'exit_time': '2018-03-26T00:00:00',
#   'entry_price': 85.982421875,
#   'exit_price': 83.72775999513816,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 6.74560546875,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 23,
#   'data_name': 'AAPL',
#   'side': 'short',
#   'entry_time': '2018-03-27T00:00:00',
#   'exit_time': '2018-03-27T00:00:00',
#   'entry_price': 41.947818756103516,
#   'exit_price': 40.84026543979377,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -23.632354736328125,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 24,
#   'data_name': 'NVDA',
#   'side': 'short',
#   'entry_time': '2018-04-02T00:00:00',
#   'exit_time': '2018-04-02T00:00:00',
#   'entry_price': 5.280589580535889,
#   'exit_price': 5.658656489559017,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 1.8782854080200195,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 25,
#   'data_name': 'AMZN',
#   'side': 'short',
#   'entry_time': '2018-04-02T00:00:00',
#   'exit_time': '2018-04-02T00:00:00',
#   'entry_price': 56.6974983215332,
#   'exit_price': 70.88099670410156,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 119.0200424194336,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 27,
#   'data_name': 'GOOG',
#   'side': 'short',
#   'entry_time': '2018-05-07T00:00:00',
#   'exit_time': '2018-05-07T00:00:00',
#   'entry_price': 50.71195983886719,
#   'exit_price': 52.1049282955762,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 16.69078826904297,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 29,
#   'data_name': 'TSLA',
#   'side': 'short',
#   'entry_time': '2018-05-25T00:00:00',
#   'exit_time': '2018-05-25T00:00:00',
#   'entry_price': 20.070667266845703,
#   'exit_price': 18.5086669921875,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -14.806671142578125,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 31,
#   'data_name': 'AMZN',
#   'side': 'short',
#   'entry_time': '2018-07-09T00:00:00',
#   'exit_time': '2018-07-09T00:00:00',
#   'entry_price': 83.26349639892578,
#   'exit_price': 86.20249938964844,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 36.875,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 35,
#   'data_name': 'NVDA',
#   'side': 'short',
#   'entry_time': '2018-09-27T00:00:00',
#   'exit_time': '2018-09-27T00:00:00',
#   'entry_price': 6.238422393798828,
#   'exit_price': 6.64603620513164,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 3.8433265686035156,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 37,
#   'data_name': 'MSFT',
#   'side': 'short',
#   'entry_time': '2018-10-12T00:00:00',
#   'exit_time': '2018-10-12T00:00:00',
#   'entry_price': 101.07168579101562,
#   'exit_price': 101.55611379111346,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 10.06134033203125,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 38,
#   'data_name': 'GOOG',
#   'side': 'short',
#   'entry_time': '2018-10-12T00:00:00',
#   'exit_time': '2018-10-12T00:00:00',
#   'entry_price': 58.01250457763672,
#   'exit_price': 55.02346153187485,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -28.857498168945312,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 39,
#   'data_name': 'AAPL',
#   'side': 'short',
#   'entry_time': '2018-10-19T00:00:00',
#   'exit_time': '2018-10-19T00:00:00',
#   'entry_price': 48.95512771606445,
#   'exit_price': 51.654330230084184,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 29.953041076660156,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 42,
#   'data_name': 'AMZN',
#   'side': 'short',
#   'entry_time': '2018-12-26T00:00:00',
#   'exit_time': '2018-12-26T00:00:00',
#   'entry_price': 82.05149841308594,
#   'exit_price': 68.44450378417969,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -85.06500244140625,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 43,
#   'data_name': 'TSLA',
#   'side': 'short',
#   'entry_time': '2018-12-27T00:00:00',
#   'exit_time': '2018-12-27T00:00:00',
#   'entry_price': 23.0939998626709,
#   'exit_price': 21.32266616821289,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -20.18667221069336,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 48,
#   'data_name': 'NVDA',
#   'side': 'short',
#   'entry_time': '2019-05-01T00:00:00',
#   'exit_time': '2019-05-01T00:00:00',
#   'entry_price': 3.6900417804718018,
#   'exit_price': 4.544341013864703,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 7.8878092765808105,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 49,
#   'data_name': 'GOOG',
#   'side': 'short',
#   'entry_time': '2019-05-08T00:00:00',
#   'exit_time': '2019-05-08T00:00:00',
#   'entry_price': 59.61653137207031,
#   'exit_price': 58.202200471349755,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -16.993789672851562,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 50,
#   'data_name': 'AAPL',
#   'side': 'short',
#   'entry_time': '2019-05-15T00:00:00',
#   'exit_time': '2019-05-15T00:00:00',
#   'entry_price': 40.70745849609375,
#   'exit_price': 44.63897868140736,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 50.45875549316406,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 51,
#   'data_name': 'MSFT',
#   'side': 'short',
#   'entry_time': '2019-06-06T00:00:00',
#   'exit_time': '2019-06-06T00:00:00',
#   'entry_price': 105.48429107666016,
#   'exit_price': 119.24820133626655,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 150.65414428710938,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 54,
#   'data_name': 'AMZN',
#   'side': 'short',
#   'entry_time': '2019-07-31T00:00:00',
#   'exit_time': '2019-07-31T00:00:00',
#   'entry_price': 95.43949890136719,
#   'exit_price': 94.90550231933594,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -21.005020141601562,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 56,
#   'data_name': 'NVDA',
#   'side': 'short',
#   'entry_time': '2019-08-08T00:00:00',
#   'exit_time': '2019-08-08T00:00:00',
#   'entry_price': 4.0307464599609375,
#   'exit_price': 3.8811748458948316,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -0.9863758087158203,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 57,
#   'data_name': 'AAPL',
#   'side': 'short',
#   'entry_time': '2019-08-09T00:00:00',
#   'exit_time': '2019-08-09T00:00:00',
#   'entry_price': 48.89271545410156,
#   'exit_price': 48.42415862155094,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -5.4312896728515625,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 60,
#   'data_name': 'MSFT',
#   'side': 'short',
#   'entry_time': '2019-10-08T00:00:00',
#   'exit_time': '2019-10-08T00:00:00',
#   'entry_price': 131.62496948242188,
#   'exit_price': 129.71355064901513,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -32.456512451171875,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 65,
#   'data_name': 'AMZN',
#   'side': 'short',
#   'entry_time': '2020-01-30T00:00:00',
#   'exit_time': '2020-01-30T00:00:00',
#   'entry_price': 93.4384994506836,
#   'exit_price': 92.9000015258789,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 0.9549713134765625,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 66,
#   'data_name': 'AAPL',
#   'side': 'short',
#   'entry_time': '2020-02-27T00:00:00',
#   'exit_time': '2020-02-27T00:00:00',
#   'entry_price': 48.74650955200195,
#   'exit_price': 67.98458625765787,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 174.04834747314453,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 67,
#   'data_name': 'GOOG',
#   'side': 'short',
#   'entry_time': '2020-03-02T00:00:00',
#   'exit_time': '2020-03-02T00:00:00',
#   'entry_price': 61.884010314941406,
#   'exit_price': 67.12117278391376,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 70.99418640136719,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 68,
#   'data_name': 'TSLA',
#   'side': 'short',
#   'entry_time': '2020-03-06T00:00:00',
#   'exit_time': '2020-03-06T00:00:00',
#   'entry_price': 21.1646671295166,
#   'exit_price': 46.0,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 257.33999252319336,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 69,
#   'data_name': 'NVDA',
#   'side': 'short',
#   'entry_time': '2020-03-10T00:00:00',
#   'exit_time': '2020-03-10T00:00:00',
#   'entry_price': 5.875504493713379,
#   'exit_price': 6.388796719236526,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 6.263551712036133,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 73,
#   'data_name': 'GOOG',
#   'side': 'short',
#   'entry_time': '2020-07-01T00:00:00',
#   'exit_time': '2020-07-01T00:00:00',
#   'entry_price': 60.10270309448242,
#   'exit_price': 70.07545467926525,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 113.10596466064453,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 76,
#   'data_name': 'TSLA',
#   'side': 'short',
#   'entry_time': '2020-08-12T00:00:00',
#   'exit_time': '2020-08-12T00:00:00',
#   'entry_price': 52.172000885009766,
#   'exit_price': 98.0,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 514.7866439819336,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 78,
#   'data_name': 'AMZN',
#   'side': 'short',
#   'entry_time': '2020-09-16T00:00:00',
#   'exit_time': '2020-09-16T00:00:00',
#   'entry_price': 123.62049865722656,
#   'exit_price': 158.99949645996094,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 302.8450012207031,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 79,
#   'data_name': 'AAPL',
#   'side': 'short',
#   'entry_time': '2020-09-17T00:00:00',
#   'exit_time': '2020-09-17T00:00:00',
#   'entry_price': 106.37797546386719,
#   'exit_price': 106.62324985916108,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 8.477706909179688,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 80,
#   'data_name': 'NVDA',
#   'side': 'short',
#   'entry_time': '2020-09-18T00:00:00',
#   'exit_time': '2020-09-18T00:00:00',
#   'entry_price': 9.579597473144531,
#   'exit_price': 12.554724352386739,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 25.71880340576172,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 81,
#   'data_name': 'MSFT',
#   'side': 'short',
#   'entry_time': '2020-09-18T00:00:00',
#   'exit_time': '2020-09-18T00:00:00',
#   'entry_price': 221.69699096679688,
#   'exit_price': 194.08651546533457,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -299.1693115234375,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 85,
#   'data_name': 'GOOG',
#   'side': 'short',
#   'entry_time': '2020-12-22T00:00:00',
#   'exit_time': '2020-12-22T00:00:00',
#   'entry_price': 77.87110900878906,
#   'exit_price': 86.132073592424,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 77.18185424804688,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 87,
#   'data_name': 'AMZN',
#   'side': 'short',
#   'entry_time': '2021-01-19T00:00:00',
#   'exit_time': '2021-01-19T00:00:00',
#   'entry_price': 160.17649841308594,
#   'exit_price': 155.35000610351562,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -41.385040283203125,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 89,
#   'data_name': 'TSLA',
#   'side': 'short',
#   'entry_time': '2021-02-10T00:00:00',
#   'exit_time': '2021-02-10T00:00:00',
#   'entry_price': 162.2133331298828,
#   'exit_price': 281.21331787109375,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 1060.6001281738281,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 90,
#   'data_name': 'AAPL',
#   'side': 'short',
#   'entry_time': '2021-02-23T00:00:00',
#   'exit_time': '2021-02-23T00:00:00',
#   'entry_price': 130.38421630859375,
#   'exit_price': 120.65447173544518,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -76.82441711425781,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 91,
#   'data_name': 'NVDA',
#   'side': 'short',
#   'entry_time': '2021-03-05T00:00:00',
#   'exit_time': '2021-03-05T00:00:00',
#   'entry_price': 13.163233757019043,
#   'exit_price': 12.514808445147853,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -7.366771697998047,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 94,
#   'data_name': 'MSFT',
#   'side': 'short',
#   'entry_time': '2021-05-07T00:00:00',
#   'exit_time': '2021-05-07T00:00:00',
#   'entry_price': 226.45359802246094,
#   'exit_price': 242.5051899813875,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 163.49746704101562,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 95,
#   'data_name': 'GOOG',
#   'side': 'short',
#   'entry_time': '2021-05-20T00:00:00',
#   'exit_time': '2021-05-20T00:00:00',
#   'entry_price': 111.719482421875,
#   'exit_price': 115.61085070914805,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 52.84332275390625,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 98,
#   'data_name': 'NVDA',
#   'side': 'short',
#   'entry_time': '2021-07-28T00:00:00',
#   'exit_time': '2021-07-28T00:00:00',
#   'entry_price': 20.4412841796875,
#   'exit_price': 19.275885189194327,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -9.818096160888672,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 99,
#   'data_name': 'AMZN',
#   'side': 'short',
#   'entry_time': '2021-08-02T00:00:00',
#   'exit_time': '2021-08-02T00:00:00',
#   'entry_price': 167.3415069580078,
#   'exit_price': 167.65499877929688,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -7.675018310546875,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 102,
#   'data_name': 'AAPL',
#   'side': 'short',
#   'entry_time': '2021-09-22T00:00:00',
#   'exit_time': '2021-09-22T00:00:00',
#   'entry_price': 143.90631103515625,
#   'exit_price': 141.27586560496235,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -12.61199951171875,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 103,
#   'data_name': 'MSFT',
#   'side': 'short',
#   'entry_time': '2021-09-22T00:00:00',
#   'exit_time': '2021-09-22T00:00:00',
#   'entry_price': 290.8554382324219,
#   'exit_price': 286.5866158831855,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -24.82086181640625,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 106,
#   'data_name': 'GOOG',
#   'side': 'short',
#   'entry_time': '2021-12-01T00:00:00',
#   'exit_time': '2021-12-01T00:00:00',
#   'entry_price': 141.44703674316406,
#   'exit_price': 143.23232011627715,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -7.915802001953125,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 108,
#   'data_name': 'AMZN',
#   'side': 'short',
#   'entry_time': '2021-12-09T00:00:00',
#   'exit_time': '2021-12-09T00:00:00',
#   'entry_price': 171.8679962158203,
#   'exit_price': 175.75,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 23.03009033203125,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 109,
#   'data_name': 'TSLA',
#   'side': 'short',
#   'entry_time': '2021-12-13T00:00:00',
#   'exit_time': '2021-12-13T00:00:00',
#   'entry_price': 390.6666564941406,
#   'exit_price': 333.6966552734375,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -685.2999877929688,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 111,
#   'data_name': 'AAPL',
#   'side': 'short',
#   'entry_time': '2022-02-25T00:00:00',
#   'exit_time': '2022-02-25T00:00:00',
#   'entry_price': 168.79832458496094,
#   'exit_price': 160.6780765984275,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -71.29730224609375,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 114,
#   'data_name': 'MSFT',
#   'side': 'short',
#   'entry_time': '2022-04-18T00:00:00',
#   'exit_time': '2022-04-18T00:00:00',
#   'entry_price': 294.8504333496094,
#   'exit_price': 270.4265639610484,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -228.6285400390625,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 115,
#   'data_name': 'GOOG',
#   'side': 'short',
#   'entry_time': '2022-04-18T00:00:00',
#   'exit_time': '2022-04-18T00:00:00',
#   'entry_price': 142.66619873046875,
#   'exit_price': 126.544028184169,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -155.74920654296875,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 117,
#   'data_name': 'AMZN',
#   'side': 'short',
#   'entry_time': '2022-06-21T00:00:00',
#   'exit_time': '2022-06-21T00:00:00',
#   'entry_price': 124.79000091552734,
#   'exit_price': 108.19999694824219,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -161.10000610351562,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 120,
#   'data_name': 'NVDA',
#   'side': 'short',
#   'entry_time': '2022-08-26T00:00:00',
#   'exit_time': '2022-08-26T00:00:00',
#   'entry_price': 17.292118072509766,
#   'exit_price': 17.82928142778485,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -10.573577880859375,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 121,
#   'data_name': 'AAPL',
#   'side': 'short',
#   'entry_time': '2022-09-02T00:00:00',
#   'exit_time': '2022-09-02T00:00:00',
#   'entry_price': 157.1525421142578,
#   'exit_price': 157.11514512449315,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -39.1241455078125,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 123,
#   'data_name': 'GOOG',
#   'side': 'short',
#   'entry_time': '2022-10-31T00:00:00',
#   'exit_time': '2022-10-31T00:00:00',
#   'entry_price': 99.60836029052734,
#   'exit_price': 95.12900725488336,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -55.9173583984375,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 130,
#   'data_name': 'GOOG',
#   'side': 'short',
#   'entry_time': '2023-06-22T00:00:00',
#   'exit_time': '2023-06-22T00:00:00',
#   'entry_price': 104.4055404663086,
#   'exit_price': 119.83990242071009,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 186.22543334960938,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 131,
#   'data_name': 'TSLA',
#   'side': 'short',
#   'entry_time': '2023-08-03T00:00:00',
#   'exit_time': '2023-08-03T00:00:00',
#   'entry_price': 188.8699951171875,
#   'exit_price': 252.0399932861328,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 704.5001220703125,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 132,
#   'data_name': 'AMZN',
#   'side': 'short',
#   'entry_time': '2023-08-03T00:00:00',
#   'exit_time': '2023-08-03T00:00:00',
#   'entry_price': 124.25,
#   'exit_price': 127.4800033569336,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 46.60003662109375,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 133,
#   'data_name': 'MSFT',
#   'side': 'short',
#   'entry_time': '2023-08-04T00:00:00',
#   'exit_time': '2023-08-04T00:00:00',
#   'entry_price': 266.5391845703125,
#   'exit_price': 325.65258996189004,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 550.9033203125,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 134,
#   'data_name': 'AAPL',
#   'side': 'short',
#   'entry_time': '2023-08-09T00:00:00',
#   'exit_time': '2023-08-09T00:00:00',
#   'entry_price': 148.5785369873047,
#   'exit_price': 178.7007682180696,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 274.7438049316406,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 135,
#   'data_name': 'NVDA',
#   'side': 'short',
#   'entry_time': '2023-08-11T00:00:00',
#   'exit_time': '2023-08-11T00:00:00',
#   'entry_price': 16.74823570251465,
#   'exit_price': 41.72064293519623,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 240.77058792114258,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 137,
#   'data_name': 'MSFT',
#   'side': 'short',
#   'entry_time': '2023-09-26T00:00:00',
#   'exit_time': '2023-09-26T00:00:00',
#   'entry_price': 327.984130859375,
#   'exit_price': 309.87152415800745,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -210.52703857421875,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 139,
#   'data_name': 'GOOG',
#   'side': 'short',
#   'entry_time': '2023-10-30T00:00:00',
#   'exit_time': '2023-10-30T00:00:00',
#   'entry_price': 139.3364715576172,
#   'exit_price': 123.61406878750469,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -144.4116973876953,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 143,
#   'data_name': 'TSLA',
#   'side': 'short',
#   'entry_time': '2024-01-11T00:00:00',
#   'exit_time': '2024-01-11T00:00:00',
#   'entry_price': 235.60000610351562,
#   'exit_price': 230.57000732421875,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -83.800048828125,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 145,
#   'data_name': 'MSFT',
#   'side': 'short',
#   'entry_time': '2024-03-12T00:00:00',
#   'exit_time': '2024-03-12T00:00:00',
#   'entry_price': 409.58050537109375,
#   'exit_price': 402.37445324131755,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 3.55377197265625,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 148,
#   'data_name': 'NVDA',
#   'side': 'short',
#   'entry_time': '2024-04-11T00:00:00',
#   'exit_time': '2024-04-11T00:00:00',
#   'entry_price': 47.542510986328125,
#   'exit_price': 87.37542414329695,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 430.2728271484375,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 149,
#   'data_name': 'MSFT',
#   'side': 'short',
#   'entry_time': '2024-04-17T00:00:00',
#   'exit_time': '2024-04-17T00:00:00',
#   'entry_price': 411.06121826171875,
#   'exit_price': 411.8804833772787,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -45.211181640625,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 150,
#   'data_name': 'AMZN',
#   'side': 'short',
#   'entry_time': '2024-04-26T00:00:00',
#   'exit_time': '2024-04-26T00:00:00',
#   'entry_price': 144.83999633789062,
#   'exit_price': 177.8000030517578,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 347.79998779296875,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 152,
#   'data_name': 'TSLA',
#   'side': 'short',
#   'entry_time': '2024-05-30T00:00:00',
#   'exit_time': '2024-05-30T00:00:00',
#   'entry_price': 184.75999450683594,
#   'exit_price': 178.5800018310547,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -59.70001220703125,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 154,
#   'data_name': 'AMZN',
#   'side': 'short',
#   'entry_time': '2024-07-24T00:00:00',
#   'exit_time': '2024-07-24T00:00:00',
#   'entry_price': 185.57000732421875,
#   'exit_price': 183.1999969482422,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -47.400054931640625,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 155,
#   'data_name': 'GOOG',
#   'side': 'short',
#   'entry_time': '2024-07-25T00:00:00',
#   'exit_time': '2024-07-25T00:00:00',
#   'entry_price': 154.81057739257812,
#   'exit_price': 173.26258432880184,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': 133.90853881835938,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 157,
#   'data_name': 'AAPL',
#   'side': 'short',
#   'entry_time': '2024-09-17T00:00:00',
#   'exit_time': '2024-09-17T00:00:00',
#   'entry_price': 223.27342224121094,
#   'exit_price': 214.54256344637628,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -76.96685791015625,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 160,
#   'data_name': 'MSFT',
#   'side': 'short',
#   'entry_time': '2024-10-11T00:00:00',
#   'exit_time': '2024-10-11T00:00:00',
#   'entry_price': 434.607666015625,
#   'exit_price': 412.26751359253427,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -221.61834716796875,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 161,
#   'data_name': 'GOOG',
#   'side': 'short',
#   'entry_time': '2024-10-23T00:00:00',
#   'exit_time': '2024-10-23T00:00:00',
#   'entry_price': 166.58091735839844,
#   'exit_price': 165.70474411550393,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -28.176727294921875,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0},
#  {'trade_id': 164,
#   'data_name': 'GOOG',
#   'side': 'short',
#   'entry_time': '2024-11-27T00:00:00',
#   'exit_time': '2024-11-27T00:00:00',
#   'entry_price': 170.39422607421875,
#   'exit_price': 169.9362333002551,
#   'size': 0.0,
#   'position_value_at_entry': 0.0,
#   'position_fraction_of_equity': 0.0,
#   'pnl_abs': -3.185882568359375,
#   'pnl_pct': 0.0,
#   'holding_period_days': 0.0}]
